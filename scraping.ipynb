# %%
import requests

# %%
url = 'https://api.golemio.cz/v2/parkingzones/'

# %%
headers = {'x-access-token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImdhcnNpbmFAZ21haWwuY29tIiwiaWQiOjkyMCwibmFtZSI6bnVsbCwic3VybmFtZSI6bnVsbCwiaWF0IjoxNjMzODU0MjgxLCJleHAiOjExNjMzODU0MjgxLCJpc3MiOiJnb2xlbWlvIiwianRpIjoiNDk0MjhkMWQtNGQ1Mi00YjIzLWJlNTItMzI1NmZmY2M2YTFiIn0.A_gD0JFXyUhQiZjhdKr8fUevc7JkfGoDPe348iA2_cI'}

# %%
r = requests.get(url, headers=headers)

# %%
print(r)
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[14.389043809000043,
#        50.090295394000066],
#       [14.38903900500003, 50.090309898000044],
#       [14.389424667000071, 50.090326951000065],
#       [14.389427241000021, 50.09031291900004],
#       [14.389043809000043, 50.090295394000066]]],
#     'type': 'Polygon'},
#    'properties': {'id': 'P1-0103',
#     'midpoint': [14.389233122936114, 50.09031117266189],
#     'name': 'P1-0103 Rezidentní úsek',
#     'northeast': [14.389427241000021, 50.090326951000065],
#     'number_of_places': 5,
#     'payment_link': 'https://ke-utc.appspot.com/static/onstreet.html?shortname=P1-0103',
#     'southwest': [14.38903900500003, 50.090295394000066],
#     'type': {'description': 'Rezidentní úsek', 'id': 1},
#     'updated_at': '2021-10-16T00:15:16.595Z',
#     'zps_id': 3311,
#     'tariffs_text': 'Po-Ne 08:00-19:59 80 Kč/hod. (max. 1 hod.); Po-Ne 20:00-05:59 80 Kč/hod. (max. 1 hod.); Po-Ne (ve svátek) 08:00-05:59 80 Kč/hod. (max. 1 hod.)',
# ...

# %%
import json

# %%
with open('zony.json', 'w') as outfile:
    json.dump(r.json(), outfile)
